# %% [markdown]
# # NYC 311 Data 에서 Air Quality 를 Query 한 데이터입니다.
#
# - 그런데 api키를 입력안해가지고 1000개 밖에 출력이 안되었습니다.
# - NYC OPENDATA 가입하시고 api 키 발급받으셔서 .json 뒤에 입력하시면 되겠습니다.
#
# - google map api, sk api랑 동일해서 다들 아실 거라고 생각해요.

# %%
# 파이썬 패키지들 입니다.
# 아나콘다로 사용하는걸 추천드려요.
# 아나콘다 패키지 설치는
# conda install [package name]
# 입니다.
# e.g. conda install geopandas
# 패키지 이름을 모르면 구글에다가 비슷한 이름으로 검색하시면되요. e.g. conda geopandas

# %matplotlib inline
import os

import numpy as np
import pandas as pd
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt

# %% [markdown]
# #### Query는 그냥 일반 기존 api 사용법이랑 비슷하구요.
# #### Spatial Query도 가능합니다.
#   - [좌상 ~ 우하] 로 설정하거나,
#   - [lat,lon, buffer size] 로 버퍼로 Query도 가능합니다.
#
# #### 그리고 데이터 타입은
#   - csv
#   - geojson
#   - json
#
# #### 으로 제공하고 있어서 geo_json 으로 하시면 사용하실때 훨씬 수월하실겁니다.

# %%
#url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.geojson?complaint_type=Air%20Quality"
#원래 리눅스 환경이면 !wget = url 하면 받아지는데 윈도우로 해서 그냥 다운로드 하고 데이터를 read 했습니다.

############# 관련 API DOCUMENTATION ##################
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv

df = gpd.read_file('../test.geojson')
df.head()
# Out:
#   location_state facility_type intersection_street_2       city location_zip  \
# 0           None           N/A                  None   BROOKLYN         None
# 1           None           N/A                  None   BROOKLYN         None
# 2           None           N/A                  None  Ridgewood         None
# 3           None           N/A                  None   BROOKLYN         None
# 4           None           N/A                  None   NEW YORK         None
#
#   park_borough            latitude road_ramp         created_date agency  \
# 0     BROOKLYN  40.631429870712815      None  2018-10-02T15:51:00    DEP
# 1     BROOKLYN    40.7085237661457      None  2018-10-02T14:21:00    DEP
# 2       QUEENS   40.71103561312886      None  2018-10-02T11:31:00    DEP
# 3     BROOKLYN   40.67221648895488      None  2018-10-02T13:26:00    DEP
# 4    MANHATTAN   40.77896735558857      None  2018-10-02T17:42:00    DEP
#
#                       ...                      \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#                               resolution_description community_board  \
# 0  The Department of Environmental Protection has...     10 BROOKLYN
# 1  The Department of Environmental Protection did...     01 BROOKLYN
# 2  The Department of Environmental Protection has...       05 QUEENS
# 3  The Department of Environmental Protection has...     08 BROOKLYN
# 4  The Department of Environmental Protection has...    08 MANHATTAN
#
#   resolution_action_updated_date intersection_street_1          closed_date  \
# 0            2018-10-03T08:48:00                  None                 None
# 1            2018-10-03T14:00:00                  None  2018-10-03T14:00:00
# 2            2018-10-03T08:31:00                  None                 None
# 3            2018-10-03T08:36:00                  None                 None
# 4            2018-10-03T08:37:00                  None                 None
#
#   vehicle_type cross_street_1    borough landmark  \
# 0         None          5 AVE   BROOKLYN     None
# 1         None         S 5 ST   BROOKLYN     None
# 2         None          88 ST     QUEENS     None
# 3         None  ST FRANCIS PL   BROOKLYN     None
# 4         None        E 86 ST  MANHATTAN     None
#
#                                      geometry
# 0  POINT (-74.02115172475099 40.631429870713)
# 1    POINT (-73.954946045586 40.708523766146)
# 2    POINT (-73.864461469221 40.711035613129)
# 3  POINT (-73.95634766269499 40.672216488955)
# 4  POINT (-73.95386571455001 40.778967355589)
#
# [5 rows x 45 columns]

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')

# %% [markdown]
# ### 그냥 이렇게 Points 별로 있는건데요. 잠깐 둘러봐도 맨하탄에 complaints가 많은 것을 알 수 있습니다. 사는 사람이 많으니깐요 ㅎㅎ.
#
# ### 수업중에 가장 많이 언급되었던 건, open date, close date가 있어서 resolution time을 계산해서 지역별로 비교하는 내용이었습니다.

# %% [markdown]
# # Amercian Community Survey API (센서스 자료)
# * API로 센서스 데이터를 받을 수 있습니다.
# * 항목도 많고 공간단위도 census tract -> state까지 다양합니다(민감한 경우에는 센서스 트랙 단위는 없는 것도 있어요).
# * [ACS-5year-Census](https://www.census.gov/data/developers/data-sets/acs-5year.html)에서 설명서를 확인하실 수 있습니다.
# * ACS 1year, 3year, 5year 가 있던데 통계방법 차이인 것 같습니다. 5년이 데이터가 제일 풍부하고 연구자들도 이걸 대부분 사용합니다.

# %% [markdown]
# * 뉴욕시에서 NYC FactFinder 라고 ACS 데이터로 플랫폼을 만들어 놓았습니다.
# * 이 툴로는 전체적인 분석은 어렵고, 어떤 데이터가 있는지 살펴보시고 이름보고 ACS API를 통해서 자료를 받으시면 되겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - NYC FactFinder UI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Census Tract를 클릭했을 때 살펴볼 수 있는 항목들, 여기서 필요한 변수를 찾아서 API를 통해 받으시면 되겠습니다.

# %%
# 변수 종류입니다. 엄청 많습니다.
df = pd.read_json('https://api.census.gov/data/2017/acs/acs5/variables.json')

# %%
df = df.reset_index()

# %%
var_names = [(var,f['label']) for var,f in zip(df['index'], df['variables'])]

# %%
var_names # 변수종류: 연령, 인종, commuting time, transportation mode 등
# Out:
# [('AIANHH', 'Geography'),
#  ('AIHHTL', 'Geography'),
#  ('AIRES', 'Geography'),
#  ('ANRC', 'Geography'),
#  ('B00001_001E', 'Estimate!!Total'),
#  ('B00002_001E', 'Estimate!!Total'),
#  ('B01001A_001E', 'Estimate!!Total'),
#  ('B01001A_002E', 'Estimate!!Total!!Male'),
#  ('B01001A_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001A_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001A_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001A_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001A_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001A_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001A_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001A_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001A_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001A_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001A_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001A_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001A_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001A_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001A_017E', 'Estimate!!Total!!Female'),
#  ('B01001A_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001A_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001A_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001A_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001A_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001A_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001A_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001A_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001A_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001A_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001A_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001A_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001A_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001A_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001B_001E', 'Estimate!!Total'),
#  ('B01001B_002E', 'Estimate!!Total!!Male'),
#  ('B01001B_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001B_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001B_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001B_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001B_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001B_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001B_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001B_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001B_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001B_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001B_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001B_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001B_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001B_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001B_017E', 'Estimate!!Total!!Female'),
#  ('B01001B_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001B_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001B_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001B_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001B_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001B_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001B_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001B_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001B_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001B_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001B_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001B_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001B_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001B_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001C_001E', 'Estimate!!Total'),
#  ('B01001C_002E', 'Estimate!!Total!!Male'),
#  ('B01001C_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001C_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001C_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001C_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001C_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001C_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001C_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001C_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001C_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001C_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001C_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001C_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001C_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001C_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001C_017E', 'Estimate!!Total!!Female'),
#  ('B01001C_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001C_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001C_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001C_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001C_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001C_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001C_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001C_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001C_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001C_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001C_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001C_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001C_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001C_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001D_001E', 'Estimate!!Total'),
#  ('B01001D_002E', 'Estimate!!Total!!Male'),
#  ('B01001D_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001D_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001D_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001D_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001D_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001D_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001D_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001D_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001D_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001D_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001D_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001D_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001D_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001D_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001D_017E', 'Estimate!!Total!!Female'),
#  ('B01001D_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001D_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001D_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001D_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001D_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001D_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001D_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001D_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001D_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001D_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001D_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001D_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001D_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001D_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001E_001E', 'Estimate!!Total'),
#  ('B01001E_002E', 'Estimate!!Total!!Male'),
#  ('B01001E_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001E_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001E_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001E_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001E_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001E_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001E_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001E_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001E_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001E_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001E_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001E_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001E_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001E_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001E_017E', 'Estimate!!Total!!Female'),
#  ('B01001E_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001E_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001E_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001E_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001E_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001E_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001E_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001E_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001E_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001E_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001E_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001E_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001E_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001E_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001F_001E', 'Estimate!!Total'),
#  ('B01001F_002E', 'Estimate!!Total!!Male'),
#  ('B01001F_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001F_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001F_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001F_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001F_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001F_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001F_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001F_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001F_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001F_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001F_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001F_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001F_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001F_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001F_017E', 'Estimate!!Total!!Female'),
#  ('B01001F_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001F_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001F_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001F_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001F_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001F_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001F_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001F_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001F_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001F_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001F_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001F_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001F_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001F_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001G_001E', 'Estimate!!Total'),
#  ('B01001G_002E', 'Estimate!!Total!!Male'),
#  ('B01001G_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001G_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001G_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001G_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001G_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001G_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001G_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001G_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001G_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001G_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001G_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001G_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001G_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001G_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001G_017E', 'Estimate!!Total!!Female'),
#  ('B01001G_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001G_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001G_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001G_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001G_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001G_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001G_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001G_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001G_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001G_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001G_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001G_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001G_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001G_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001H_001E', 'Estimate!!Total'),
#  ('B01001H_002E', 'Estimate!!Total!!Male'),
#  ('B01001H_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001H_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001H_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001H_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001H_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001H_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001H_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001H_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001H_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001H_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001H_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001H_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001H_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001H_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001H_017E', 'Estimate!!Total!!Female'),
#  ('B01001H_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001H_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001H_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001H_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001H_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001H_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001H_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001H_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001H_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001H_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001H_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001H_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001H_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001H_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001I_001E', 'Estimate!!Total'),
#  ('B01001I_002E', 'Estimate!!Total!!Male'),
#  ('B01001I_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001I_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001I_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001I_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001I_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001I_008E', 'Estimate!!Total!!Male!!20 to 24 years'),
#  ('B01001I_009E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001I_010E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001I_011E', 'Estimate!!Total!!Male!!35 to 44 years'),
#  ('B01001I_012E', 'Estimate!!Total!!Male!!45 to 54 years'),
#  ('B01001I_013E', 'Estimate!!Total!!Male!!55 to 64 years'),
#  ('B01001I_014E', 'Estimate!!Total!!Male!!65 to 74 years'),
#  ('B01001I_015E', 'Estimate!!Total!!Male!!75 to 84 years'),
#  ('B01001I_016E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001I_017E', 'Estimate!!Total!!Female'),
#  ('B01001I_018E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001I_019E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001I_020E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001I_021E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001I_022E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001I_023E', 'Estimate!!Total!!Female!!20 to 24 years'),
#  ('B01001I_024E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001I_025E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001I_026E', 'Estimate!!Total!!Female!!35 to 44 years'),
#  ('B01001I_027E', 'Estimate!!Total!!Female!!45 to 54 years'),
#  ('B01001I_028E', 'Estimate!!Total!!Female!!55 to 64 years'),
#  ('B01001I_029E', 'Estimate!!Total!!Female!!65 to 74 years'),
#  ('B01001I_030E', 'Estimate!!Total!!Female!!75 to 84 years'),
#  ('B01001I_031E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01001_001E', 'Estimate!!Total'),
#  ('B01001_002E', 'Estimate!!Total!!Male'),
#  ('B01001_003E', 'Estimate!!Total!!Male!!Under 5 years'),
#  ('B01001_004E', 'Estimate!!Total!!Male!!5 to 9 years'),
#  ('B01001_005E', 'Estimate!!Total!!Male!!10 to 14 years'),
#  ('B01001_006E', 'Estimate!!Total!!Male!!15 to 17 years'),
#  ('B01001_007E', 'Estimate!!Total!!Male!!18 and 19 years'),
#  ('B01001_008E', 'Estimate!!Total!!Male!!20 years'),
#  ('B01001_009E', 'Estimate!!Total!!Male!!21 years'),
#  ('B01001_010E', 'Estimate!!Total!!Male!!22 to 24 years'),
#  ('B01001_011E', 'Estimate!!Total!!Male!!25 to 29 years'),
#  ('B01001_012E', 'Estimate!!Total!!Male!!30 to 34 years'),
#  ('B01001_013E', 'Estimate!!Total!!Male!!35 to 39 years'),
#  ('B01001_014E', 'Estimate!!Total!!Male!!40 to 44 years'),
#  ('B01001_015E', 'Estimate!!Total!!Male!!45 to 49 years'),
#  ('B01001_016E', 'Estimate!!Total!!Male!!50 to 54 years'),
#  ('B01001_017E', 'Estimate!!Total!!Male!!55 to 59 years'),
#  ('B01001_018E', 'Estimate!!Total!!Male!!60 and 61 years'),
#  ('B01001_019E', 'Estimate!!Total!!Male!!62 to 64 years'),
#  ('B01001_020E', 'Estimate!!Total!!Male!!65 and 66 years'),
#  ('B01001_021E', 'Estimate!!Total!!Male!!67 to 69 years'),
#  ('B01001_022E', 'Estimate!!Total!!Male!!70 to 74 years'),
#  ('B01001_023E', 'Estimate!!Total!!Male!!75 to 79 years'),
#  ('B01001_024E', 'Estimate!!Total!!Male!!80 to 84 years'),
#  ('B01001_025E', 'Estimate!!Total!!Male!!85 years and over'),
#  ('B01001_026E', 'Estimate!!Total!!Female'),
#  ('B01001_027E', 'Estimate!!Total!!Female!!Under 5 years'),
#  ('B01001_028E', 'Estimate!!Total!!Female!!5 to 9 years'),
#  ('B01001_029E', 'Estimate!!Total!!Female!!10 to 14 years'),
#  ('B01001_030E', 'Estimate!!Total!!Female!!15 to 17 years'),
#  ('B01001_031E', 'Estimate!!Total!!Female!!18 and 19 years'),
#  ('B01001_032E', 'Estimate!!Total!!Female!!20 years'),
#  ('B01001_033E', 'Estimate!!Total!!Female!!21 years'),
#  ('B01001_034E', 'Estimate!!Total!!Female!!22 to 24 years'),
#  ('B01001_035E', 'Estimate!!Total!!Female!!25 to 29 years'),
#  ('B01001_036E', 'Estimate!!Total!!Female!!30 to 34 years'),
#  ('B01001_037E', 'Estimate!!Total!!Female!!35 to 39 years'),
#  ('B01001_038E', 'Estimate!!Total!!Female!!40 to 44 years'),
#  ('B01001_039E', 'Estimate!!Total!!Female!!45 to 49 years'),
#  ('B01001_040E', 'Estimate!!Total!!Female!!50 to 54 years'),
#  ('B01001_041E', 'Estimate!!Total!!Female!!55 to 59 years'),
#  ('B01001_042E', 'Estimate!!Total!!Female!!60 and 61 years'),
#  ('B01001_043E', 'Estimate!!Total!!Female!!62 to 64 years'),
#  ('B01001_044E', 'Estimate!!Total!!Female!!65 and 66 years'),
#  ('B01001_045E', 'Estimate!!Total!!Female!!67 to 69 years'),
#  ('B01001_046E', 'Estimate!!Total!!Female!!70 to 74 years'),
#  ('B01001_047E', 'Estimate!!Total!!Female!!75 to 79 years'),
#  ('B01001_048E', 'Estimate!!Total!!Female!!80 to 84 years'),
#  ('B01001_049E', 'Estimate!!Total!!Female!!85 years and over'),
#  ('B01002A_001E', 'Estimate!!Median age!!Total'),
#  ('B01002A_002E', 'Estimate!!Median age!!Male'),
#  ('B01002A_003E', 'Estimate!!Median age!!Female'),
#  ('B01002B_001E', 'Estimate!!Median age!!Total'),
#  ('B01002B_002E', 'Estimate!!Median age!!Male'),
#  ('B01002B_003E', 'Estimate!!Median age!!Female'),
#  ('B01002C_001E', 'Estimate!!Median age!!Total'),
#  ('B01002C_002E', 'Estimate!!Median age!!Male'),
#  ('B01002C_003E', 'Estimate!!Median age!!Female'),
#  ('B01002D_001E', 'Estimate!!Median age!!Total'),
#  ('B01002D_002E', 'Estimate!!Median age!!Male'),
#  ('B01002D_003E', 'Estimate!!Median age!!Female'),
#  ('B01002E_001E', 'Estimate!!Median age!!Total'),
#  ('B01002E_002E', 'Estimate!!Median age!!Male'),
#  ('B01002E_003E', 'Estimate!!Median age!!Female'),
#  ('B01002F_001E', 'Estimate!!Median age!!Total'),
#  ('B01002F_002E', 'Estimate!!Median age!!Male'),
#  ('B01002F_003E', 'Estimate!!Median age!!Female'),
#  ('B01002G_001E', 'Estimate!!Median age!!Total'),
#  ('B01002G_002E', 'Estimate!!Median age!!Male'),
#  ('B01002G_003E', 'Estimate!!Median age!!Female'),
#  ('B01002H_001E', 'Estimate!!Median age!!Total'),
#  ('B01002H_002E', 'Estimate!!Median age!!Male'),
#  ('B01002H_003E', 'Estimate!!Median age!!Female'),
#  ('B01002I_001E', 'Estimate!!Median age!!Total'),
#  ('B01002I_002E', 'Estimate!!Median age!!Male'),
#  ('B01002I_003E', 'Estimate!!Median age!!Female'),
#  ('B01002_001E', 'Estimate!!Median age!!Total'),
#  ('B01002_002E', 'Estimate!!Median age!!Male'),
#  ('B01002_003E', 'Estimate!!Median age!!Female'),
#  ('B01003_001E', 'Estimate!!Total'),
#  ('B02001_001E', 'Estimate!!Total'),
#  ('B02001_002E', 'Estimate!!Total!!White alone'),
#  ('B02001_003E', 'Estimate!!Total!!Black or African American alone'),
#  ('B02001_004E', 'Estimate!!Total!!American Indian and Alaska Native alone'),
#  ('B02001_005E', 'Estimate!!Total!!Asian alone'),
#  ('B02001_006E',
#   'Estimate!!Total!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B02001_007E', 'Estimate!!Total!!Some other race alone'),
#  ('B02001_008E', 'Estimate!!Total!!Two or more races'),
#  ('B02001_009E',
#   'Estimate!!Total!!Two or more races!!Two races including Some other race'),
#  ('B02001_010E',
#   'Estimate!!Total!!Two or more races!!Two races excluding Some other race and three or more races'),
#  ('B02008_001E', 'Estimate!!Total'),
#  ('B02009_001E', 'Estimate!!Total'),
#  ('B02010_001E', 'Estimate!!Total'),
#  ('B02011_001E', 'Estimate!!Total'),
#  ('B02012_001E', 'Estimate!!Total'),
#  ('B02013_001E', 'Estimate!!Total'),
#  ('B02014_001E', 'Estimate!!Total'),
#  ('B02014_002E', 'Estimate!!Total!!American Indian tribes specified'),
#  ('B02014_003E', 'Estimate!!Total!!American Indian tribes specified!!Apache'),
#  ('B02014_004E', 'Estimate!!Total!!American Indian tribes specified!!Arapaho'),
#  ('B02014_005E',
#   'Estimate!!Total!!American Indian tribes specified!!Blackfeet'),
#  ('B02014_006E',
#   'Estimate!!Total!!American Indian tribes specified!!Canadian and French American Indian'),
#  ('B02014_007E',
#   'Estimate!!Total!!American Indian tribes specified!!Central American Indian'),
#  ('B02014_008E',
#   'Estimate!!Total!!American Indian tribes specified!!Cherokee'),
#  ('B02014_009E',
#   'Estimate!!Total!!American Indian tribes specified!!Cheyenne'),
#  ('B02014_010E',
#   'Estimate!!Total!!American Indian tribes specified!!Chickasaw'),
#  ('B02014_011E',
#   'Estimate!!Total!!American Indian tribes specified!!Chippewa'),
#  ('B02014_012E', 'Estimate!!Total!!American Indian tribes specified!!Choctaw'),
#  ('B02014_013E',
#   'Estimate!!Total!!American Indian tribes specified!!Colville'),
#  ('B02014_014E',
#   'Estimate!!Total!!American Indian tribes specified!!Comanche'),
#  ('B02014_015E', 'Estimate!!Total!!American Indian tribes specified!!Cree'),
#  ('B02014_016E', 'Estimate!!Total!!American Indian tribes specified!!Creek'),
#  ('B02014_017E', 'Estimate!!Total!!American Indian tribes specified!!Crow'),
#  ('B02014_018E',
#   'Estimate!!Total!!American Indian tribes specified!!Delaware'),
#  ('B02014_019E', 'Estimate!!Total!!American Indian tribes specified!!Hopi'),
#  ('B02014_020E', 'Estimate!!Total!!American Indian tribes specified!!Houma'),
#  ('B02014_021E',
#   'Estimate!!Total!!American Indian tribes specified!!Iroquois'),
#  ('B02014_022E', 'Estimate!!Total!!American Indian tribes specified!!Kiowa'),
#  ('B02014_023E', 'Estimate!!Total!!American Indian tribes specified!!Lumbee'),
#  ('B02014_024E',
#   'Estimate!!Total!!American Indian tribes specified!!Menominee'),
#  ('B02014_025E',
#   'Estimate!!Total!!American Indian tribes specified!!Mexican American Indian'),
#  ('B02014_026E', 'Estimate!!Total!!American Indian tribes specified!!Navajo'),
#  ('B02014_027E', 'Estimate!!Total!!American Indian tribes specified!!Osage'),
#  ('B02014_028E', 'Estimate!!Total!!American Indian tribes specified!!Ottawa'),
#  ('B02014_029E', 'Estimate!!Total!!American Indian tribes specified!!Paiute'),
#  ('B02014_030E', 'Estimate!!Total!!American Indian tribes specified!!Pima'),
#  ('B02014_031E',
#   'Estimate!!Total!!American Indian tribes specified!!Potawatomi'),
#  ('B02014_032E', 'Estimate!!Total!!American Indian tribes specified!!Pueblo'),
#  ('B02014_033E',
#   'Estimate!!Total!!American Indian tribes specified!!Puget Sound Salish'),
#  ('B02014_034E',
#   'Estimate!!Total!!American Indian tribes specified!!Seminole'),
#  ('B02014_035E',
#   'Estimate!!Total!!American Indian tribes specified!!Shoshone'),
#  ('B02014_036E', 'Estimate!!Total!!American Indian tribes specified!!Sioux'),
#  ('B02014_037E',
#   'Estimate!!Total!!American Indian tribes specified!!South American Indian'),
#  ('B02014_038E',
#   'Estimate!!Total!!American Indian tribes specified!!Spanish American Indian'),
#  ('B02014_039E',
#   "Estimate!!Total!!American Indian tribes specified!!Tohono O'Odham"),
#  ('B02014_040E', 'Estimate!!Total!!American Indian tribes specified!!Ute'),
#  ('B02014_041E', 'Estimate!!Total!!American Indian tribes specified!!Yakama'),
#  ('B02014_042E', 'Estimate!!Total!!American Indian tribes specified!!Yaqui'),
#  ('B02014_043E', 'Estimate!!Total!!American Indian tribes specified!!Yuman'),
#  ('B02014_044E',
#   'Estimate!!Total!!American Indian tribes specified!!All other American Indian tribes (with only one tribe reported)'),
#  ('B02014_045E', 'Estimate!!Total!!American Indian tribes not specified'),
#  ('B02014_046E', 'Estimate!!Total!!Alaska Native tribes specified'),
#  ('B02014_047E',
#   'Estimate!!Total!!Alaska Native tribes specified!!Alaskan Athabascan'),
#  ('B02014_048E', 'Estimate!!Total!!Alaska Native tribes specified!!Aleut'),
#  ('B02014_049E', 'Estimate!!Total!!Alaska Native tribes specified!!Inupiat'),
#  ('B02014_050E',
#   'Estimate!!Total!!Alaska Native tribes specified!!Tlingit-Haida'),
#  ('B02014_051E', 'Estimate!!Total!!Alaska Native tribes specified!!Tsimshian'),
#  ('B02014_052E', "Estimate!!Total!!Alaska Native tribes specified!!Yup'ik"),
#  ('B02014_053E', 'Estimate!!Total!!Alaska Native tribes not specified'),
#  ('B02014_054E',
#   'Estimate!!Total!!American Indian or Alaska Native tribes not specified'),
#  ('B02014_055E',
#   'Estimate!!Total!!Two or More American Indian or Alaska Native Tribes'),
#  ('B02015_001E', 'Estimate!!Total'),
#  ('B02015_002E', 'Estimate!!Total!!Asian Indian'),
#  ('B02015_003E', 'Estimate!!Total!!Bangladeshi'),
#  ('B02015_004E', 'Estimate!!Total!!Bhutanese'),
#  ('B02015_005E', 'Estimate!!Total!!Burmese'),
#  ('B02015_006E', 'Estimate!!Total!!Cambodian'),
#  ('B02015_007E', 'Estimate!!Total!!Chinese except Taiwanese'),
#  ('B02015_008E', 'Estimate!!Total!!Filipino'),
#  ('B02015_009E', 'Estimate!!Total!!Hmong'),
#  ('B02015_010E', 'Estimate!!Total!!Indonesian'),
#  ('B02015_011E', 'Estimate!!Total!!Japanese'),
#  ('B02015_012E', 'Estimate!!Total!!Korean'),
#  ('B02015_013E', 'Estimate!!Total!!Laotian'),
#  ('B02015_014E', 'Estimate!!Total!!Malaysian'),
#  ('B02015_015E', 'Estimate!!Total!!Mongolian'),
#  ('B02015_016E', 'Estimate!!Total!!Nepalese'),
#  ('B02015_017E', 'Estimate!!Total!!Okinawan'),
#  ('B02015_018E', 'Estimate!!Total!!Pakistani'),
#  ('B02015_019E', 'Estimate!!Total!!Sri Lankan'),
#  ('B02015_020E', 'Estimate!!Total!!Taiwanese'),
#  ('B02015_021E', 'Estimate!!Total!!Thai'),
#  ('B02015_022E', 'Estimate!!Total!!Vietnamese'),
#  ('B02015_023E', 'Estimate!!Total!!Other Asian specified'),
#  ('B02015_024E', 'Estimate!!Total!!Other Asian not specified'),
#  ('B02015_025E', 'Estimate!!Total!!Two or more Asian'),
#  ('B02016_001E', 'Estimate!!Total'),
#  ('B02016_002E', 'Estimate!!Total!!Polynesian!!Native Hawaiian'),
#  ('B02016_003E', 'Estimate!!Total!!Polynesian!!Samoan'),
#  ('B02016_004E', 'Estimate!!Total!!Polynesian!!Tongan'),
#  ('B02016_005E', 'Estimate!!Total!!Polynesian!!Other Polynesian'),
#  ('B02016_006E', 'Estimate!!Total!!Micronesian!!Guamanian or Chamorro'),
#  ('B02016_007E', 'Estimate!!Total!!Micronesian!!Marshallese'),
#  ('B02016_008E', 'Estimate!!Total!!Micronesian!!Other Micronesian'),
#  ('B02016_009E', 'Estimate!!Total!!Melanesian!!Fijian'),
#  ('B02016_010E', 'Estimate!!Total!!Melanesian!!Other Melanesian'),
#  ('B02016_011E',
#   'Estimate!!Total!!Other Pacific Islander not specified (check box only)'),
#  ('B02016_012E', 'Estimate!!Total!!Two or More NHPI'),
#  ('B02017_001E', 'Estimate!!Total Groups Tallied'),
#  ('B02017_002E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified'),
#  ('B02017_003E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Apache'),
#  ('B02017_004E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Arapaho'),
#  ('B02017_005E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Blackfeet'),
#  ('B02017_006E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Canadian and French American Indian'),
#  ('B02017_007E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Central American Indian'),
#  ('B02017_008E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Cherokee'),
#  ('B02017_009E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Cheyenne'),
#  ('B02017_010E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Chickasaw'),
#  ('B02017_011E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Chippewa'),
#  ('B02017_012E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Choctaw'),
#  ('B02017_013E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Colville'),
#  ('B02017_014E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Comanche'),
#  ('B02017_015E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Cree'),
#  ('B02017_016E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Creek'),
#  ('B02017_017E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Crow'),
#  ('B02017_018E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Delaware'),
#  ('B02017_019E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Hopi'),
#  ('B02017_020E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Houma'),
#  ('B02017_021E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Iroquois'),
#  ('B02017_022E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Kiowa'),
#  ('B02017_023E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Lumbee'),
#  ('B02017_024E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Menominee'),
#  ('B02017_025E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Mexican American Indian'),
#  ('B02017_026E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Navajo'),
#  ('B02017_027E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Osage'),
#  ('B02017_028E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Ottawa'),
#  ('B02017_029E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Paiute'),
#  ('B02017_030E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Pima'),
#  ('B02017_031E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Potawatomi'),
#  ('B02017_032E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Pueblo'),
#  ('B02017_033E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Puget Sound Salish'),
#  ('B02017_034E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Seminole'),
#  ('B02017_035E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Shoshone'),
#  ('B02017_036E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Sioux'),
#  ('B02017_037E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!South American Indian'),
#  ('B02017_038E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Spanish American Indian'),
#  ('B02017_039E',
#   "Estimate!!Total Groups Tallied!!American Indian tribes specified!!Tohono O'Odham"),
#  ('B02017_040E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Ute'),
#  ('B02017_041E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Yakama'),
#  ('B02017_042E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Yaqui'),
#  ('B02017_043E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!Yuman'),
#  ('B02017_044E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes specified!!All other American Indian tribes (with only one tribe reported)'),
#  ('B02017_045E',
#   'Estimate!!Total Groups Tallied!!American Indian tribes not specified'),
#  ('B02017_046E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified'),
#  ('B02017_047E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Alaskan Athabascan'),
#  ('B02017_048E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Aleut'),
#  ('B02017_049E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Inupiat'),
#  ('B02017_050E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Tlingit-Haida'),
#  ('B02017_051E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Tsimshian'),
#  ('B02017_052E',
#   "Estimate!!Total Groups Tallied!!Alaska Native tribes specified!!Yup'ik"),
#  ('B02017_053E',
#   'Estimate!!Total Groups Tallied!!Alaska Native tribes not specified'),
#  ('B02017_054E',
#   'Estimate!!Total Groups Tallied!!American Indian or Alaska Native tribes not specified'),
#  ('B02018_001E', 'Estimate!!Total Groups Tallied'),
#  ('B02018_002E', 'Estimate!!Total Groups Tallied!!Asian Indian'),
#  ('B02018_003E', 'Estimate!!Total Groups Tallied!!Bangladeshi'),
#  ('B02018_004E', 'Estimate!!Total Groups Tallied!!Bhutanese'),
#  ('B02018_005E', 'Estimate!!Total Groups Tallied!!Burmese'),
#  ('B02018_006E', 'Estimate!!Total Groups Tallied!!Cambodian'),
#  ('B02018_007E', 'Estimate!!Total Groups Tallied!!Chinese except Taiwanese'),
#  ('B02018_008E', 'Estimate!!Total Groups Tallied!!Filipino'),
#  ('B02018_009E', 'Estimate!!Total Groups Tallied!!Hmong'),
#  ('B02018_010E', 'Estimate!!Total Groups Tallied!!Indonesian'),
#  ('B02018_011E', 'Estimate!!Total Groups Tallied!!Japanese'),
#  ('B02018_012E', 'Estimate!!Total Groups Tallied!!Korean'),
#  ('B02018_013E', 'Estimate!!Total Groups Tallied!!Laotian'),
#  ('B02018_014E', 'Estimate!!Total Groups Tallied!!Malaysian'),
#  ('B02018_015E', 'Estimate!!Total Groups Tallied!!Mongolian'),
#  ('B02018_016E', 'Estimate!!Total Groups Tallied!!Nepalese'),
#  ('B02018_017E', 'Estimate!!Total Groups Tallied!!Okinawan'),
#  ('B02018_018E', 'Estimate!!Total Groups Tallied!!Pakistani'),
#  ('B02018_019E', 'Estimate!!Total Groups Tallied!!Sri Lankan'),
#  ('B02018_020E', 'Estimate!!Total Groups Tallied!!Taiwanese'),
#  ('B02018_021E', 'Estimate!!Total Groups Tallied!!Thai'),
#  ('B02018_022E', 'Estimate!!Total Groups Tallied!!Vietnamese'),
#  ('B02018_023E', 'Estimate!!Total Groups Tallied!!Other Asian specified'),
#  ('B02018_024E', 'Estimate!!Total Groups Tallied!!Other Asian not specified'),
#  ('B02019_001E', 'Estimate!!Total Groups Tallied'),
#  ('B02019_002E',
#   'Estimate!!Total Groups Tallied!!Polynesian!!Native Hawaiian'),
#  ('B02019_003E', 'Estimate!!Total Groups Tallied!!Polynesian!!Samoan'),
#  ('B02019_004E', 'Estimate!!Total Groups Tallied!!Polynesian!!Tongan'),
#  ('B02019_005E',
#   'Estimate!!Total Groups Tallied!!Polynesian!!Other Polynesian'),
#  ('B02019_006E',
#   'Estimate!!Total Groups Tallied!!Micronesian!!Guamanian or Chamorro'),
#  ('B02019_007E', 'Estimate!!Total Groups Tallied!!Micronesian!!Marshallese'),
#  ('B02019_008E',
#   'Estimate!!Total Groups Tallied!!Micronesian!!Other Micronesian'),
#  ('B02019_009E', 'Estimate!!Total Groups Tallied!!Melanesian!!Fijian'),
#  ('B02019_010E',
#   'Estimate!!Total Groups Tallied!!Melanesian!!Other Melanesian'),
#  ('B02019_011E',
#   'Estimate!!Total Groups Tallied!!Other Pacific Islander not specified'),
#  ('B03001_001E', 'Estimate!!Total'),
#  ('B03001_002E', 'Estimate!!Total!!Not Hispanic or Latino'),
#  ('B03001_003E', 'Estimate!!Total!!Hispanic or Latino'),
#  ('B03001_004E', 'Estimate!!Total!!Hispanic or Latino!!Mexican'),
#  ('B03001_005E', 'Estimate!!Total!!Hispanic or Latino!!Puerto Rican'),
#  ('B03001_006E', 'Estimate!!Total!!Hispanic or Latino!!Cuban'),
#  ('B03001_007E',
#   'Estimate!!Total!!Hispanic or Latino!!Dominican (Dominican Republic)'),
#  ('B03001_008E', 'Estimate!!Total!!Hispanic or Latino!!Central American'),
#  ('B03001_009E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Costa Rican'),
#  ('B03001_010E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Guatemalan'),
#  ('B03001_011E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Honduran'),
#  ('B03001_012E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Nicaraguan'),
#  ('B03001_013E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Panamanian'),
#  ('B03001_014E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Salvadoran'),
#  ('B03001_015E',
#   'Estimate!!Total!!Hispanic or Latino!!Central American!!Other Central American'),
#  ('B03001_016E', 'Estimate!!Total!!Hispanic or Latino!!South American'),
#  ('B03001_017E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Argentinean'),
#  ('B03001_018E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Bolivian'),
#  ('B03001_019E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Chilean'),
#  ('B03001_020E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Colombian'),
#  ('B03001_021E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Ecuadorian'),
#  ('B03001_022E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Paraguayan'),
#  ('B03001_023E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Peruvian'),
#  ('B03001_024E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Uruguayan'),
#  ('B03001_025E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Venezuelan'),
#  ('B03001_026E',
#   'Estimate!!Total!!Hispanic or Latino!!South American!!Other South American'),
#  ('B03001_027E',
#   'Estimate!!Total!!Hispanic or Latino!!Other Hispanic or Latino'),
#  ('B03001_028E',
#   'Estimate!!Total!!Hispanic or Latino!!Other Hispanic or Latino!!Spaniard'),
#  ('B03001_029E',
#   'Estimate!!Total!!Hispanic or Latino!!Other Hispanic or Latino!!Spanish'),
#  ('B03001_030E',
#   'Estimate!!Total!!Hispanic or Latino!!Other Hispanic or Latino!!Spanish American'),
#  ('B03001_031E',
#   'Estimate!!Total!!Hispanic or Latino!!Other Hispanic or Latino!!All other Hispanic or Latino'),
#  ('B03002_001E', 'Estimate!!Total'),
#  ('B03002_002E', 'Estimate!!Total!!Not Hispanic or Latino'),
#  ('B03002_003E', 'Estimate!!Total!!Not Hispanic or Latino!!White alone'),
#  ('B03002_004E',
#   'Estimate!!Total!!Not Hispanic or Latino!!Black or African American alone'),
#  ('B03002_005E',
#   'Estimate!!Total!!Not Hispanic or Latino!!American Indian and Alaska Native alone'),
#  ('B03002_006E', 'Estimate!!Total!!Not Hispanic or Latino!!Asian alone'),
#  ('B03002_007E',
#   'Estimate!!Total!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_008E',
#   'Estimate!!Total!!Not Hispanic or Latino!!Some other race alone'),
#  ('B03002_009E', 'Estimate!!Total!!Not Hispanic or Latino!!Two or more races'),
#  ('B03002_010E',
#   'Estimate!!Total!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race'),
#  ('B03002_011E',
#   'Estimate!!Total!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race and three or more races'),
#  ('B03002_012E', 'Estimate!!Total!!Hispanic or Latino'),
#  ('B03002_013E', 'Estimate!!Total!!Hispanic or Latino!!White alone'),
#  ('B03002_014E',
#   'Estimate!!Total!!Hispanic or Latino!!Black or African American alone'),
#  ('B03002_015E',
#   'Estimate!!Total!!Hispanic or Latino!!American Indian and Alaska Native alone'),
#  ('B03002_016E', 'Estimate!!Total!!Hispanic or Latino!!Asian alone'),
#  ('B03002_017E',
#   'Estimate!!Total!!Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone'),
#  ('B03002_018E', 'Estimate!!Total!!Hispanic or Latino!!Some other race alone'),
#  ('B03002_019E', 'Estimate!!Total!!Hispanic or Latino!!Two or more races'),
#  ('B03002_020E',
#   'Estimate!!Total!!Hispanic or Latino!!Two or more races!!Two races including Some other race'),
#  ('B03002_021E',
#   'Estimate!!Total!!Hispanic or Latino!!Two or more races!!Two races excluding Some other race and three or more races'),
#  ('B03003_001E', 'Estimate!!Total'),
#  ('B03003_002E', 'Estimate!!Total!!Not Hispanic or Latino'),
#  ('B03003_003E', 'Estimate!!Total!!Hispanic or Latino'),
#  ('B04004_001E', 'Estimate!!Total'),
#  ('B04004_002E', 'Estimate!!Total!!Afghan'),
#  ('B04004_003E', 'Estimate!!Total!!Albanian'),
#  ('B04004_004E', 'Estimate!!Total!!Alsatian'),
#  ('B04004_005E', 'Estimate!!Total!!American'),
#  ('B04004_006E', 'Estimate!!Total!!Arab'),
#  ('B04004_007E', 'Estimate!!Total!!Arab!!Egyptian'),
#  ('B04004_008E', 'Estimate!!Total!!Arab!!Iraqi'),
#  ('B04004_009E', 'Estimate!!Total!!Arab!!Jordanian'),
#  ('B04004_010E', 'Estimate!!Total!!Arab!!Lebanese'),
#  ('B04004_011E', 'Estimate!!Total!!Arab!!Moroccan'),
#  ('B04004_012E', 'Estimate!!Total!!Arab!!Palestinian'),
#  ('B04004_013E', 'Estimate!!Total!!Arab!!Syrian'),
#  ('B04004_014E', 'Estimate!!Total!!Arab!!Arab'),
#  ('B04004_015E', 'Estimate!!Total!!Arab!!Other Arab'),
#  ('B04004_016E', 'Estimate!!Total!!Armenian'),
#  ('B04004_017E', 'Estimate!!Total!!Assyrian/Chaldean/Syriac'),
#  ('B04004_018E', 'Estimate!!Total!!Australian'),
#  ('B04004_019E', 'Estimate!!Total!!Austrian'),
#  ('B04004_020E', 'Estimate!!Total!!Basque'),
#  ('B04004_021E', 'Estimate!!Total!!Belgian'),
#  ('B04004_022E', 'Estimate!!Total!!Brazilian'),
#  ('B04004_023E', 'Estimate!!Total!!British'),
#  ('B04004_024E', 'Estimate!!Total!!Bulgarian'),
#  ('B04004_025E', 'Estimate!!Total!!Cajun'),
#  ('B04004_026E', 'Estimate!!Total!!Canadian'),
#  ('B04004_027E', 'Estimate!!Total!!Carpatho Rusyn'),
#  ('B04004_028E', 'Estimate!!Total!!Celtic'),
#  ('B04004_029E', 'Estimate!!Total!!Croatian'),
#  ('B04004_030E', 'Estimate!!Total!!Cypriot'),
#  ('B04004_031E', 'Estimate!!Total!!Czech'),
#  ('B04004_032E', 'Estimate!!Total!!Czechoslovakian'),
#  ('B04004_033E', 'Estimate!!Total!!Danish'),
#  ('B04004_034E', 'Estimate!!Total!!Dutch'),
#  ('B04004_035E', 'Estimate!!Total!!Eastern European'),
#  ('B04004_036E', 'Estimate!!Total!!English'),
#  ('B04004_037E', 'Estimate!!Total!!Estonian'),
#  ('B04004_038E', 'Estimate!!Total!!European'),
#  ('B04004_039E', 'Estimate!!Total!!Finnish'),
#  ('B04004_040E', 'Estimate!!Total!!French (except Basque)'),
#  ('B04004_041E', 'Estimate!!Total!!French Canadian'),
#  ('B04004_042E', 'Estimate!!Total!!German'),
#  ('B04004_043E', 'Estimate!!Total!!German Russian'),
#  ('B04004_044E', 'Estimate!!Total!!Greek'),
#  ('B04004_045E', 'Estimate!!Total!!Guyanese'),
#  ('B04004_046E', 'Estimate!!Total!!Hungarian'),
#  ('B04004_047E', 'Estimate!!Total!!Icelander'),
#  ('B04004_048E', 'Estimate!!Total!!Iranian'),
#  ('B04004_049E', 'Estimate!!Total!!Irish'),
#  ('B04004_050E', 'Estimate!!Total!!Israeli'),
#  ('B04004_051E', 'Estimate!!Total!!Italian'),
#  ('B04004_052E', 'Estimate!!Total!!Latvian'),
#  ('B04004_053E', 'Estimate!!Total!!Lithuanian'),
#  ('B04004_054E', 'Estimate!!Total!!Luxemburger'),
#  ('B04004_055E', 'Estimate!!Total!!Macedonian'),
#  ('B04004_056E', 'Estimate!!Total!!Maltese'),
#  ('B04004_057E', 'Estimate!!Total!!New Zealander'),
#  ('B04004_058E', 'Estimate!!Total!!Northern European'),
#  ('B04004_059E', 'Estimate!!Total!!Norwegian'),
#  ('B04004_060E', 'Estimate!!Total!!Pennsylvania German'),
#  ('B04004_061E', 'Estimate!!Total!!Polish'),
#  ('B04004_062E', 'Estimate!!Total!!Portuguese'),
#  ('B04004_063E', 'Estimate!!Total!!Romanian'),
#  ('B04004_064E', 'Estimate!!Total!!Russian'),
#  ('B04004_065E', 'Estimate!!Total!!Scandinavian'),
#  ('B04004_066E', 'Estimate!!Total!!Scotch-Irish'),
#  ('B04004_067E', 'Estimate!!Total!!Scottish'),
#  ('B04004_068E', 'Estimate!!Total!!Serbian'),
#  ('B04004_069E', 'Estimate!!Total!!Slavic'),
#  ('B04004_070E', 'Estimate!!Total!!Slovak'),
#  ('B04004_071E', 'Estimate!!Total!!Slovene'),
#  ('B04004_072E', 'Estimate!!Total!!Soviet Union'),
#  ('B04004_073E', 'Estimate!!Total!!Subsaharan African'),
#  ('B04004_074E', 'Estimate!!Total!!Subsaharan African!!Cape Verdean'),
#  ('B04004_075E', 'Estimate!!Total!!Subsaharan African!!Ethiopian'),
#  ('B04004_076E', 'Estimate!!Total!!Subsaharan African!!Ghanaian'),
#  ('B04004_077E', 'Estimate!!Total!!Subsaharan African!!Kenyan'),
#  ('B04004_078E', 'Estimate!!Total!!Subsaharan African!!Liberian'),
#  ('B04004_079E', 'Estimate!!Total!!Subsaharan African!!Nigerian'),
#  ('B04004_080E', 'Estimate!!Total!!Subsaharan African!!Senegalese'),
#  ('B04004_081E', 'Estimate!!Total!!Subsaharan African!!Sierra Leonean'),
#  ('B04004_082E', 'Estimate!!Total!!Subsaharan African!!Somali'),
#  ('B04004_083E', 'Estimate!!Total!!Subsaharan African!!South African'),
#  ('B04004_084E', 'Estimate!!Total!!Subsaharan African!!Sudanese'),
#  ('B04004_085E', 'Estimate!!Total!!Subsaharan African!!Ugandan'),
#  ('B04004_086E', 'Estimate!!Total!!Subsaharan African!!Zimbabwean'),
#  ('B04004_087E', 'Estimate!!Total!!Subsaharan African!!African'),
#  ('B04004_088E',
#   'Estimate!!Total!!Subsaharan African!!Other Subsaharan African'),
#  ('B04004_089E', 'Estimate!!Total!!Swedish'),
#  ('B04004_090E', 'Estimate!!Total!!Swiss'),
#  ('B04004_091E', 'Estimate!!Total!!Turkish'),
#  ('B04004_092E', 'Estimate!!Total!!Ukrainian'),
#  ('B04004_093E', 'Estimate!!Total!!Welsh'),
#  ('B04004_094E', 'Estimate!!Total!!West Indian (except Hispanic groups)'),
#  ('B04004_095E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bahamian'),
#  ('B04004_096E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Barbadian'),
#  ('B04004_097E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Belizean'),
#  ('B04004_098E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bermudan'),
#  ('B04004_099E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!British West Indian'),
#  ('B04004_100E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Dutch West Indian'),
#  ('B04004_101E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Haitian'),
#  ('B04004_102E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Jamaican'),
#  ('B04004_103E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Trinidadian and Tobagonian'),
#  ('B04004_104E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!U.S. Virgin Islander'),
#  ('B04004_105E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!West Indian'),
#  ('B04004_106E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Other West Indian'),
#  ('B04004_107E', 'Estimate!!Total!!Yugoslavian'),
#  ('B04004_108E', 'Estimate!!Total!!Other groups'),
#  ('B04005_001E', 'Estimate!!Total'),
#  ('B04005_002E', 'Estimate!!Total!!Afghan'),
#  ('B04005_003E', 'Estimate!!Total!!Albanian'),
#  ('B04005_004E', 'Estimate!!Total!!Alsatian'),
#  ('B04005_005E', 'Estimate!!Total!!American'),
#  ('B04005_006E', 'Estimate!!Total!!Arab'),
#  ('B04005_007E', 'Estimate!!Total!!Arab!!Egyptian'),
#  ('B04005_008E', 'Estimate!!Total!!Arab!!Iraqi'),
#  ('B04005_009E', 'Estimate!!Total!!Arab!!Jordanian'),
#  ('B04005_010E', 'Estimate!!Total!!Arab!!Lebanese'),
#  ('B04005_011E', 'Estimate!!Total!!Arab!!Moroccan'),
#  ('B04005_012E', 'Estimate!!Total!!Arab!!Palestinian'),
#  ('B04005_013E', 'Estimate!!Total!!Arab!!Syrian'),
#  ('B04005_014E', 'Estimate!!Total!!Arab!!Arab'),
#  ('B04005_015E', 'Estimate!!Total!!Arab!!Other Arab'),
#  ('B04005_016E', 'Estimate!!Total!!Armenian'),
#  ('B04005_017E', 'Estimate!!Total!!Assyrian/Chaldean/Syriac'),
#  ('B04005_018E', 'Estimate!!Total!!Australian'),
#  ('B04005_019E', 'Estimate!!Total!!Austrian'),
#  ('B04005_020E', 'Estimate!!Total!!Basque'),
#  ('B04005_021E', 'Estimate!!Total!!Belgian'),
#  ('B04005_022E', 'Estimate!!Total!!Brazilian'),
#  ('B04005_023E', 'Estimate!!Total!!British'),
#  ('B04005_024E', 'Estimate!!Total!!Bulgarian'),
#  ('B04005_025E', 'Estimate!!Total!!Cajun'),
#  ('B04005_026E', 'Estimate!!Total!!Canadian'),
#  ('B04005_027E', 'Estimate!!Total!!Carpatho Rusyn'),
#  ('B04005_028E', 'Estimate!!Total!!Celtic'),
#  ('B04005_029E', 'Estimate!!Total!!Croatian'),
#  ('B04005_030E', 'Estimate!!Total!!Cypriot'),
#  ('B04005_031E', 'Estimate!!Total!!Czech'),
#  ('B04005_032E', 'Estimate!!Total!!Czechoslovakian'),
#  ('B04005_033E', 'Estimate!!Total!!Danish'),
#  ('B04005_034E', 'Estimate!!Total!!Dutch'),
#  ('B04005_035E', 'Estimate!!Total!!Eastern European'),
#  ('B04005_036E', 'Estimate!!Total!!English'),
#  ('B04005_037E', 'Estimate!!Total!!Estonian'),
#  ('B04005_038E', 'Estimate!!Total!!European'),
#  ('B04005_039E', 'Estimate!!Total!!Finnish'),
#  ('B04005_040E', 'Estimate!!Total!!French (except Basque)'),
#  ('B04005_041E', 'Estimate!!Total!!French Canadian'),
#  ('B04005_042E', 'Estimate!!Total!!German'),
#  ('B04005_043E', 'Estimate!!Total!!German Russian'),
#  ('B04005_044E', 'Estimate!!Total!!Greek'),
#  ('B04005_045E', 'Estimate!!Total!!Guyanese'),
#  ('B04005_046E', 'Estimate!!Total!!Hungarian'),
#  ('B04005_047E', 'Estimate!!Total!!Icelander'),
#  ('B04005_048E', 'Estimate!!Total!!Iranian'),
#  ('B04005_049E', 'Estimate!!Total!!Irish'),
#  ('B04005_050E', 'Estimate!!Total!!Israeli'),
#  ('B04005_051E', 'Estimate!!Total!!Italian'),
#  ('B04005_052E', 'Estimate!!Total!!Latvian'),
#  ('B04005_053E', 'Estimate!!Total!!Lithuanian'),
#  ('B04005_054E', 'Estimate!!Total!!Luxemburger'),
#  ('B04005_055E', 'Estimate!!Total!!Macedonian'),
#  ('B04005_056E', 'Estimate!!Total!!Maltese'),
#  ('B04005_057E', 'Estimate!!Total!!New Zealander'),
#  ('B04005_058E', 'Estimate!!Total!!Northern European'),
#  ('B04005_059E', 'Estimate!!Total!!Norwegian'),
#  ('B04005_060E', 'Estimate!!Total!!Pennsylvania German'),
#  ('B04005_061E', 'Estimate!!Total!!Polish'),
#  ('B04005_062E', 'Estimate!!Total!!Portuguese'),
#  ('B04005_063E', 'Estimate!!Total!!Romanian'),
#  ('B04005_064E', 'Estimate!!Total!!Russian'),
#  ('B04005_065E', 'Estimate!!Total!!Scandinavian'),
#  ('B04005_066E', 'Estimate!!Total!!Scotch-Irish'),
#  ('B04005_067E', 'Estimate!!Total!!Scottish'),
#  ('B04005_068E', 'Estimate!!Total!!Serbian'),
#  ('B04005_069E', 'Estimate!!Total!!Slavic'),
#  ('B04005_070E', 'Estimate!!Total!!Slovak'),
#  ('B04005_071E', 'Estimate!!Total!!Slovene'),
#  ('B04005_072E', 'Estimate!!Total!!Soviet Union'),
#  ('B04005_073E', 'Estimate!!Total!!Subsaharan African'),
#  ('B04005_074E', 'Estimate!!Total!!Subsaharan African!!Cape Verdean'),
#  ('B04005_075E', 'Estimate!!Total!!Subsaharan African!!Ethiopian'),
#  ('B04005_076E', 'Estimate!!Total!!Subsaharan African!!Ghanaian'),
#  ('B04005_077E', 'Estimate!!Total!!Subsaharan African!!Kenyan'),
#  ('B04005_078E', 'Estimate!!Total!!Subsaharan African!!Liberian'),
#  ('B04005_079E', 'Estimate!!Total!!Subsaharan African!!Nigerian'),
#  ('B04005_080E', 'Estimate!!Total!!Subsaharan African!!Senegalese'),
#  ('B04005_081E', 'Estimate!!Total!!Subsaharan African!!Sierra Leonean'),
#  ('B04005_082E', 'Estimate!!Total!!Subsaharan African!!Somali'),
#  ('B04005_083E', 'Estimate!!Total!!Subsaharan African!!South African'),
#  ('B04005_084E', 'Estimate!!Total!!Subsaharan African!!Sudanese'),
#  ('B04005_085E', 'Estimate!!Total!!Subsaharan African!!Ugandan'),
#  ('B04005_086E', 'Estimate!!Total!!Subsaharan African!!Zimbabwean'),
#  ('B04005_087E', 'Estimate!!Total!!Subsaharan African!!African'),
#  ('B04005_088E',
#   'Estimate!!Total!!Subsaharan African!!Other Subsaharan African'),
#  ('B04005_089E', 'Estimate!!Total!!Swedish'),
#  ('B04005_090E', 'Estimate!!Total!!Swiss'),
#  ('B04005_091E', 'Estimate!!Total!!Turkish'),
#  ('B04005_092E', 'Estimate!!Total!!Ukrainian'),
#  ('B04005_093E', 'Estimate!!Total!!Welsh'),
#  ('B04005_094E', 'Estimate!!Total!!West Indian (except Hispanic groups)'),
#  ('B04005_095E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bahamian'),
#  ('B04005_096E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Barbadian'),
#  ('B04005_097E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Belizean'),
#  ('B04005_098E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bermudan'),
#  ('B04005_099E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!British West Indian'),
#  ('B04005_100E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Dutch West Indian'),
#  ('B04005_101E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Haitian'),
#  ('B04005_102E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Jamaican'),
#  ('B04005_103E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Trinidadian and Tobagonian'),
#  ('B04005_104E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!U.S. Virgin Islander'),
#  ('B04005_105E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!West Indian'),
#  ('B04005_106E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Other West Indian'),
#  ('B04005_107E', 'Estimate!!Total!!Yugoslavian'),
#  ('B04005_108E', 'Estimate!!Total!!Other groups'),
#  ('B04006_001E', 'Estimate!!Total'),
#  ('B04006_002E', 'Estimate!!Total!!Afghan'),
#  ('B04006_003E', 'Estimate!!Total!!Albanian'),
#  ('B04006_004E', 'Estimate!!Total!!Alsatian'),
#  ('B04006_005E', 'Estimate!!Total!!American'),
#  ('B04006_006E', 'Estimate!!Total!!Arab'),
#  ('B04006_007E', 'Estimate!!Total!!Arab!!Egyptian'),
#  ('B04006_008E', 'Estimate!!Total!!Arab!!Iraqi'),
#  ('B04006_009E', 'Estimate!!Total!!Arab!!Jordanian'),
#  ('B04006_010E', 'Estimate!!Total!!Arab!!Lebanese'),
#  ('B04006_011E', 'Estimate!!Total!!Arab!!Moroccan'),
#  ('B04006_012E', 'Estimate!!Total!!Arab!!Palestinian'),
#  ('B04006_013E', 'Estimate!!Total!!Arab!!Syrian'),
#  ('B04006_014E', 'Estimate!!Total!!Arab!!Arab'),
#  ('B04006_015E', 'Estimate!!Total!!Arab!!Other Arab'),
#  ('B04006_016E', 'Estimate!!Total!!Armenian'),
#  ('B04006_017E', 'Estimate!!Total!!Assyrian/Chaldean/Syriac'),
#  ('B04006_018E', 'Estimate!!Total!!Australian'),
#  ('B04006_019E', 'Estimate!!Total!!Austrian'),
#  ('B04006_020E', 'Estimate!!Total!!Basque'),
#  ('B04006_021E', 'Estimate!!Total!!Belgian'),
#  ('B04006_022E', 'Estimate!!Total!!Brazilian'),
#  ('B04006_023E', 'Estimate!!Total!!British'),
#  ('B04006_024E', 'Estimate!!Total!!Bulgarian'),
#  ('B04006_025E', 'Estimate!!Total!!Cajun'),
#  ('B04006_026E', 'Estimate!!Total!!Canadian'),
#  ('B04006_027E', 'Estimate!!Total!!Carpatho Rusyn'),
#  ('B04006_028E', 'Estimate!!Total!!Celtic'),
#  ('B04006_029E', 'Estimate!!Total!!Croatian'),
#  ('B04006_030E', 'Estimate!!Total!!Cypriot'),
#  ('B04006_031E', 'Estimate!!Total!!Czech'),
#  ('B04006_032E', 'Estimate!!Total!!Czechoslovakian'),
#  ('B04006_033E', 'Estimate!!Total!!Danish'),
#  ('B04006_034E', 'Estimate!!Total!!Dutch'),
#  ('B04006_035E', 'Estimate!!Total!!Eastern European'),
#  ('B04006_036E', 'Estimate!!Total!!English'),
#  ('B04006_037E', 'Estimate!!Total!!Estonian'),
#  ('B04006_038E', 'Estimate!!Total!!European'),
#  ('B04006_039E', 'Estimate!!Total!!Finnish'),
#  ('B04006_040E', 'Estimate!!Total!!French (except Basque)'),
#  ('B04006_041E', 'Estimate!!Total!!French Canadian'),
#  ('B04006_042E', 'Estimate!!Total!!German'),
#  ('B04006_043E', 'Estimate!!Total!!German Russian'),
#  ('B04006_044E', 'Estimate!!Total!!Greek'),
#  ('B04006_045E', 'Estimate!!Total!!Guyanese'),
#  ('B04006_046E', 'Estimate!!Total!!Hungarian'),
#  ('B04006_047E', 'Estimate!!Total!!Icelander'),
#  ('B04006_048E', 'Estimate!!Total!!Iranian'),
#  ('B04006_049E', 'Estimate!!Total!!Irish'),
#  ('B04006_050E', 'Estimate!!Total!!Israeli'),
#  ('B04006_051E', 'Estimate!!Total!!Italian'),
#  ('B04006_052E', 'Estimate!!Total!!Latvian'),
#  ('B04006_053E', 'Estimate!!Total!!Lithuanian'),
#  ('B04006_054E', 'Estimate!!Total!!Luxemburger'),
#  ('B04006_055E', 'Estimate!!Total!!Macedonian'),
#  ('B04006_056E', 'Estimate!!Total!!Maltese'),
#  ('B04006_057E', 'Estimate!!Total!!New Zealander'),
#  ('B04006_058E', 'Estimate!!Total!!Northern European'),
#  ('B04006_059E', 'Estimate!!Total!!Norwegian'),
#  ('B04006_060E', 'Estimate!!Total!!Pennsylvania German'),
#  ('B04006_061E', 'Estimate!!Total!!Polish'),
#  ('B04006_062E', 'Estimate!!Total!!Portuguese'),
#  ('B04006_063E', 'Estimate!!Total!!Romanian'),
#  ('B04006_064E', 'Estimate!!Total!!Russian'),
#  ('B04006_065E', 'Estimate!!Total!!Scandinavian'),
#  ('B04006_066E', 'Estimate!!Total!!Scotch-Irish'),
#  ('B04006_067E', 'Estimate!!Total!!Scottish'),
#  ('B04006_068E', 'Estimate!!Total!!Serbian'),
#  ('B04006_069E', 'Estimate!!Total!!Slavic'),
#  ('B04006_070E', 'Estimate!!Total!!Slovak'),
#  ('B04006_071E', 'Estimate!!Total!!Slovene'),
#  ('B04006_072E', 'Estimate!!Total!!Soviet Union'),
#  ('B04006_073E', 'Estimate!!Total!!Subsaharan African'),
#  ('B04006_074E', 'Estimate!!Total!!Subsaharan African!!Cape Verdean'),
#  ('B04006_075E', 'Estimate!!Total!!Subsaharan African!!Ethiopian'),
#  ('B04006_076E', 'Estimate!!Total!!Subsaharan African!!Ghanaian'),
#  ('B04006_077E', 'Estimate!!Total!!Subsaharan African!!Kenyan'),
#  ('B04006_078E', 'Estimate!!Total!!Subsaharan African!!Liberian'),
#  ('B04006_079E', 'Estimate!!Total!!Subsaharan African!!Nigerian'),
#  ('B04006_080E', 'Estimate!!Total!!Subsaharan African!!Senegalese'),
#  ('B04006_081E', 'Estimate!!Total!!Subsaharan African!!Sierra Leonean'),
#  ('B04006_082E', 'Estimate!!Total!!Subsaharan African!!Somali'),
#  ('B04006_083E', 'Estimate!!Total!!Subsaharan African!!South African'),
#  ('B04006_084E', 'Estimate!!Total!!Subsaharan African!!Sudanese'),
#  ('B04006_085E', 'Estimate!!Total!!Subsaharan African!!Ugandan'),
#  ('B04006_086E', 'Estimate!!Total!!Subsaharan African!!Zimbabwean'),
#  ('B04006_087E', 'Estimate!!Total!!Subsaharan African!!African'),
#  ('B04006_088E',
#   'Estimate!!Total!!Subsaharan African!!Other Subsaharan African'),
#  ('B04006_089E', 'Estimate!!Total!!Swedish'),
#  ('B04006_090E', 'Estimate!!Total!!Swiss'),
#  ('B04006_091E', 'Estimate!!Total!!Turkish'),
#  ('B04006_092E', 'Estimate!!Total!!Ukrainian'),
#  ('B04006_093E', 'Estimate!!Total!!Welsh'),
#  ('B04006_094E', 'Estimate!!Total!!West Indian (except Hispanic groups)'),
#  ('B04006_095E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bahamian'),
#  ('B04006_096E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Barbadian'),
#  ('B04006_097E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Belizean'),
#  ('B04006_098E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Bermudan'),
#  ('B04006_099E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!British West Indian'),
#  ('B04006_100E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Dutch West Indian'),
#  ('B04006_101E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Haitian'),
#  ('B04006_102E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Jamaican'),
#  ('B04006_103E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Trinidadian and Tobagonian'),
#  ('B04006_104E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!U.S. Virgin Islander'),
#  ('B04006_105E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!West Indian'),
#  ('B04006_106E',
#   'Estimate!!Total!!West Indian (except Hispanic groups)!!Other West Indian'),
#  ('B04006_107E', 'Estimate!!Total!!Yugoslavian'),
#  ('B04006_108E', 'Estimate!!Total!!Other groups'),
#  ('B04006_109E', 'Estimate!!Total!!Unclassified or not reported'),
#  ('B04007_001E', 'Estimate!!Total'),
#  ('B04007_002E', 'Estimate!!Total!!Ancestry specified'),
#  ('B04007_003E', 'Estimate!!Total!!Ancestry specified!!Single ancestry'),
#  ('B04007_004E', 'Estimate!!Total!!Ancestry specified!!Multiple ancestry'),
#  ('B04007_005E', 'Estimate!!Total!!Ancestry not specified'),
#  ('B04007_006E',
#   'Estimate!!Total!!Ancestry not specified!!Ancestry unclassified'),
#  ('B04007_007E',
#   'Estimate!!Total!!Ancestry not specified!!Ancestry not reported'),
#  ('B05001PR_001E', 'Estimate!!Total'),
#  ('B05001PR_002E', 'Estimate!!Total!!U.S. citizen born in Puerto Rico'),
#  ('B05001PR_003E',
#   'Estimate!!Total!!U.S. citizen born in U.S. or U.S. Island Areas'),
#  ('B05001PR_004E',
#   'Estimate!!Total!!U.S. citizen born abroad of American parent(s)'),
#  ('B05001PR_005E', 'Estimate!!Total!!U.S. citizen by naturalization'),
#  ('B05001PR_006E', 'Estimate!!Total!!Not a U.S. citizen'),
#  ('B05001_001E', 'Estimate!!Total'),
#  ('B05001_002E', 'Estimate!!Total!!U.S. citizen born in the United States'),
#  ('B05001_003E',
#   'Estimate!!Total!!U.S. citizen born in Puerto Rico or U.S. Island Areas'),
#  ('B05001_004E',
#   'Estimate!!Total!!U.S. citizen born abroad of American parent(s)'),
#  ('B05001_005E', 'Estimate!!Total!!U.S. citizen by naturalization'),
#  ('B05001_006E', 'Estimate!!Total!!Not a U.S. citizen'),
#  ('B05002_001E', 'Estimate!!Total'),
#  ('B05002_002E', 'Estimate!!Total!!Native'),
#  ('B05002_003E', 'Estimate!!Total!!Native!!Born in state of residence'),
#  ('B05002_004E',
#   'Estimate!!Total!!Native!!Born in other state in the United States'),
#  ('B05002_005E',
#   'Estimate!!Total!!Native!!Born in other state in the United States!!Northeast'),
#  ('B05002_006E',
#   'Estimate!!Total!!Native!!Born in other state in the United States!!Midwest'),
#  ('B05002_007E',
#   'Estimate!!Total!!Native!!Born in other state in the United States!!South'),
#  ('B05002_008E',
#   'Estimate!!Total!!Native!!Born in other state in the United States!!West'),
#  ('B05002_009E', 'Estimate!!Total!!Native!!Born outside the United States'),
#  ('B05002_010E',
#   'Estimate!!Total!!Native!!Born outside the United States!!Puerto Rico'),
#  ('B05002_011E',
#   'Estimate!!Total!!Native!!Born outside the United States!!U.S. Island Areas'),
#  ('B05002_012E',
#   'Estimate!!Total!!Native!!Born outside the United States!!Born abroad of American parent(s)'),
#  ('B05002_013E', 'Estimate!!Total!!Foreign born'),
#  ('B05002_014E', 'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen'),
#  ('B05002_015E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Europe'),
#  ('B05002_016E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Asia'),
#  ('B05002_017E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Africa'),
#  ('B05002_018E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Oceania'),
#  ('B05002_019E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Latin America'),
#  ('B05002_020E',
#   'Estimate!!Total!!Foreign born!!Naturalized U.S. citizen!!Northern America'),
#  ('B05002_021E', 'Estimate!!Total!!Foreign born!!Not a U.S. citizen'),
#  ('B05002_022E', 'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Europe'),
#  ('B05002_023E', 'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Asia'),
#  ('B05002_024E', 'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Africa'),
#  ('B05002_025E', 'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Oceania'),
#  ('B05002_026E',
#   'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Latin America'),
#  ('B05002_027E',
#   'Estimate!!Total!!Foreign born!!Not a U.S. citizen!!Northern America'),
#  ('B05003A_001E', 'Estimate!!Total'),
#  ('B05003A_002E', 'Estimate!!Total!!Male'),
#  ('B05003A_003E', 'Estimate!!Total!!Male!!Under 18 years'),
#  ('B05003A_004E', 'Estimate!!Total!!Male!!Under 18 years!!Native'),
#  ('B05003A_005E', 'Estimate!!Total!!Male!!Under 18 years!!Foreign born'),
#  ('B05003A_006E',
#   'Estimate!!Total!!Male!!Under 18 years!!Foreign born!!Naturalized U.S. citizen'),
#  ('B05003A_007E',
#   'Estimate!!Total!!Male!!Under 18 years!!Foreign born!!Not a U.S. citizen'),
#  ('B05003A_008E', 'Estimate!!Total!!Male!!18 years and over'),
#  ('B05003A_009E', 'Estimate!!Total!!Male!!18 years and over!!Native'),
#  ('B05003A_010E', 'Estimate!!Total!!Male!!18 years and over!!Foreign born'),
#  ('B05003A_011E',
#   'Estimate!!Total!!Male!!18 years and over!!Foreign born!!Naturalized U.S. citizen'),
#  ('B05003A_012E',
#   'Estimate!!Total!!Male!!18 years and over!!Foreign born!!Not a U.S. citizen'),
#  ...]

# %%
print('ACS에 있는 변수는 총 {}개 입니다.'.format(len(var_names)))
# Out:
# ACS에 있는 변수는 총 25110개 입니다.

# %%
# Korean 항목이 있는지 한번 보겠습니다.
korean_var = []
for i in range(len(var_names)):
    if 'Korean' in var_names[i][1]:
        print(var_names[i])
# Out:
# ('B02015_012E', 'Estimate!!Total!!Korean')
# ('B02018_012E', 'Estimate!!Total Groups Tallied!!Korean')
# ('B16001_081E', 'Estimate!!Total!!Korean')
# ('B16001_082E', 'Estimate!!Total!!Korean!!Speak English very well')
# ('B16001_083E', 'Estimate!!Total!!Korean!!Speak English less than very well')
# ('B21002_007E', 'Estimate!!Total!!Vietnam Era no Korean War no World War II')
# ('B21002_008E', 'Estimate!!Total!!Vietnam Era and Korean War no World War II')
# ('B21002_009E', 'Estimate!!Total!!Vietnam Era and Korean War and World War II')
# ('B21002_010E', 'Estimate!!Total!!Korean War no Vietnam Era no World War II')
# ('B21002_011E', 'Estimate!!Total!!Korean War and World War II no Vietnam Era')
# ('B21002_012E', 'Estimate!!Total!!World War II no Korean War no Vietnam Era')
# ('B21002_014E', 'Estimate!!Total!!Between Vietnam Era and Korean War only')
# ('B21002_015E', 'Estimate!!Total!!Between Korean War and World War II only')
# ('C16001_018E', 'Estimate!!Total!!Korean')
# ('C16001_019E', 'Estimate!!Total!!Korean!!Speak English very well')
# ('C16001_020E', 'Estimate!!Total!!Korean!!Speak English less than very well')

# %%
# list(map(lambda v:var_names[v],korean_var))

# %%
# 오.. 토탈 코리안 분포로 한국인들이 어디 사는지 한번 보겠습니다!
# code name: B02015_012E
# NY State Code = 36
# Sample Code는 다음과 같습니다:
# https://api.census.gov/data/2017/acs/acs5?get=B01001_001E,NAME&for=tract:*&in=state:36%20county:*

url = 'https://api.census.gov/data/2017/acs/acs5?get=B02015_012E,NAME&for=tract:*&in=state:36%20county:*'
kor_pop = pd.read_json(url)
col_name = [n for n in kor_pop.iloc[0]]
kor_pop.columns = col_name
kor_pop.drop(kor_pop.head(1).index, inplace=True)

# %%
kor_pop.head()
# Out:
#   B02015_012E                                       NAME state county   tract
# 1          11  Census Tract 119, Queens County, New York    36    081  011900
# 2           0  Census Tract 135, Queens County, New York    36    081  013500
# 3           0  Census Tract 136, Queens County, New York    36    081  013600
# 4           0  Census Tract 141, Queens County, New York    36    081  014100
# 5           0  Census Tract 145, Queens County, New York    36    081  014500

# %%
ct2010 = pd.read_csv('https://data.cityofnewyork.us/api/views/i69b-3rdj/rows.csv?accessType=api')

# %%
gdf = gpd.GeoDataFrame(ct2010)
gdf['the_geom'] = gdf['the_geom'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(gdf, geometry='the_geom')

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf.plot(ax=ax)
plt.show()
