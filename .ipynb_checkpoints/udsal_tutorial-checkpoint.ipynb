# %%
import numpy as np
import pandas as pd
from mapboxgl.utils import create_color_stops, df_to_geojson
from mapboxgl.viz import CircleViz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-fe4729c37a15> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from mapboxgl.utils import create_color_stops, df_to_geojson
#       4 from mapboxgl.viz import CircleViz
#
# ImportError: No module named 'mapboxgl'

# %%
url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json?complaint_type=Air%20Quality"
df = pd.read_json(url)
df.head(8)
# Out:
#    address_type agency                             agency_name           bbl  \
# 0       ADDRESS    DEP  Department of Environmental Protection  1.010150e+09
# 1       ADDRESS    DEP  Department of Environmental Protection  1.020700e+09
# 2       ADDRESS    DEP  Department of Environmental Protection  1.010830e+09
# 3  INTERSECTION    DEP  Department of Environmental Protection           NaN
# 4       ADDRESS    DEP  Department of Environmental Protection  1.022430e+09
# 5       ADDRESS    DEP  Department of Environmental Protection  4.000400e+09
# 6       ADDRESS    DEP  Department of Environmental Protection  4.003120e+09
# 7       ADDRESS    DEP  Department of Environmental Protection  4.096310e+09
#
#      borough              city closed_date community_board complaint_type  \
# 0  MANHATTAN          NEW YORK         NaN    05 MANHATTAN    Air Quality
# 1  MANHATTAN          NEW YORK         NaN    09 MANHATTAN    Air Quality
# 2  MANHATTAN          NEW YORK         NaN    04 MANHATTAN    Air Quality
# 3     QUEENS          Flushing         NaN       08 QUEENS    Air Quality
# 4  MANHATTAN          NEW YORK         NaN    12 MANHATTAN    Air Quality
# 5     QUEENS  Long Island City         NaN       02 QUEENS    Air Quality
# 6     QUEENS  Long Island City         NaN       02 QUEENS    Air Quality
# 7     QUEENS     Richmond Hill         NaN       09 QUEENS    Air Quality
#
#               created_date           ...            open_data_channel_type  \
# 0  2018-10-03T12:19:00.000           ...                             PHONE
# 1  2018-10-03T21:08:00.000           ...                             PHONE
# 2  2018-10-03T10:06:00.000           ...                             PHONE
# 3  2018-10-03T15:22:00.000           ...                             PHONE
# 4  2018-10-03T12:37:00.000           ...                            ONLINE
# 5  2018-10-03T14:21:00.000           ...                             PHONE
# 6  2018-10-03T07:08:00.000           ...                             PHONE
# 7  2018-10-03T16:44:00.000           ...                             PHONE
#
#   park_borough park_facility_name resolution_action_updated_date  \
# 0    MANHATTAN        Unspecified                            NaN
# 1    MANHATTAN        Unspecified                            NaN
# 2    MANHATTAN        Unspecified                            NaN
# 3       QUEENS        Unspecified                            NaN
# 4    MANHATTAN        Unspecified                            NaN
# 5       QUEENS        Unspecified                            NaN
# 6       QUEENS        Unspecified        2018-10-03T08:44:00.000
# 7       QUEENS        Unspecified                            NaN
#
#                               resolution_description   status  \
# 0                                                NaN     Open
# 1                                                NaN     Open
# 2                                                NaN     Open
# 3                                                NaN     Open
# 4                                                NaN     Open
# 5                                                NaN     Open
# 6  The Department of Environmental Protection has...  Started
# 7                                                NaN     Open
#
#            street_name unique_key  x_coordinate_state_plane  \
# 0     WEST   44 STREET   40454997                  987653.0
# 1     AMSTERDAM AVENUE   40452310                  997925.0
# 2     WEST   55 STREET   40452252                  986857.0
# 3                  NaN   40451480                 1032908.0
# 4    PARK TERRACE EAST   40451397                 1007400.0
# 5            51 AVENUE   40451504                  997232.0
# 6      RAILROAD AVENUE   40451928                 1001498.0
# 7  VAN WYCK EXPRESSWAY   40451356                 1034470.0
#
#   y_coordinate_state_plane
# 0                 215454.0
# 1                 238455.0
# 2                 219174.0
# 3                 200112.0
# 4                 256483.0
# 5                 209543.0
# 6                 205977.0
# 7                 196634.0
#
# [8 rows x 31 columns]

# %%
import os

import pandas as pd


# Load data from sample csv
data_url = 'https://raw.githubusercontent.com/mapbox/mapboxgl-jupyter/master/examples/data/points.csv'
df = pd.read_csv(data_url)

# Must be a public token, starting with `pk`
token = os.getenv('MAPBOX_ACCESS_TOKEN')

# Create a geojson file export from a Pandas dataframe
df_to_geojson(df, filename='points.geojson',
              properties=['Avg Medicare Payments', 'Avg Covered Charges', 'date'],
              lat='lat', lon='lon', precision=3)

# Generate data breaks and color stops from colorBrewer
color_breaks = [0,10,100,1000,10000]
color_stops = create_color_stops(color_breaks, colors='YlGnBu')

# Create the viz from the dataframe
viz = CircleViz('points.geojson',
                access_token=token,
                height='400px',
                color_property = "Avg Medicare Payments",
                color_stops = color_stops,
                center = (-95, 40),
                zoom = 3,
                below_layer = 'waterway-label'
              )
viz.show()
